# %% [markdown]
# Data Visualization might be very difficult for Pandas beginners.
#
# Here is a dataset on Ice Cream Rating I created with random numbers and some basic visualizations with matplotlib.
#
# I hope you can get your hands busy with this. Have fun !!

# %% [markdown]
# Import Libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Create a Dictionary

# %%
data = {
    'Date': ['2023/10/18','2023/01/15','2023/07/5','2023/05/15','2023/04/14','2023/06/5','2023/06/26','2023/09/24','2023/01/23','2023/10/20'],
    'Mat Ice Rating': list(np.random.random(size=10)),
    'Kada Ice Rating': list(np.random.random(size=10)),
    'Overall Rating': list(np.random.random(size=10))
}

# %% [markdown]
# Converting dictionary to a DataFrame

# %%
data = pd.DataFrame(data)

# %% [markdown]
# Update column Date
#
# Convert Date from object to datetime and strip off hours

# %%
data["Date"] = pd.to_datetime(data["Date"])

data["Date"] = data["Date"].dt.date

# %% [markdown]
# View the Dataset

# %%
data.head(10)
# Out:
#          Date  Mat Ice Rating  Kada Ice Rating  Overall Rating
# 0  2023-10-18        0.721922         0.000573        0.476132
# 1  2023-01-15        0.419637         0.348263        0.203916
# 2  2023-07-05        0.680508         0.515850        0.284076
# 3  2023-05-15        0.286892         0.554687        0.257247
# 4  2023-04-14        0.647959         0.605508        0.575199
# 5  2023-06-05        0.771146         0.379842        0.553286
# 6  2023-06-26        0.211967         0.135644        0.146494
# 7  2023-09-24        0.672065         0.551064        0.930635
# 8  2023-01-23        0.377907         0.253299        0.639560
# 9  2023-10-20        0.874099         0.403046        0.304331

# %% [markdown]
# Set the column Date as Index

# %%
data.set_index('Date', inplace=True)

data
# Out:
#             Mat Ice Rating  Kada Ice Rating  Overall Rating
# Date
# 2023-10-18        0.721922         0.000573        0.476132
# 2023-01-15        0.419637         0.348263        0.203916
# 2023-07-05        0.680508         0.515850        0.284076
# 2023-05-15        0.286892         0.554687        0.257247
# 2023-04-14        0.647959         0.605508        0.575199
# 2023-06-05        0.771146         0.379842        0.553286
# 2023-06-26        0.211967         0.135644        0.146494
# 2023-09-24        0.672065         0.551064        0.930635
# 2023-01-23        0.377907         0.253299        0.639560
# 2023-10-20        0.874099         0.403046        0.304331

# %% [markdown]
# View available plot style in matplotlib

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# Plot Visuals
# - Line
# - Box
# - Bar
# - Barh
# - Pie
# - Scatter

# %%
data.plot.line(subplots=True, figsize=(13,10), title="Ice Rating",ylabel="Rating",
               color=['navy','royalblue', 'skyblue'])
plt.show()

# %%
data.plot.box(title='Box Visual', color='cornflowerblue')
plt.show()

# %%
data.plot.bar(figsize=(20,10), title='Bar Visual', color=['navy','royalblue', 'cornflowerblue'])
plt.show()

# %%
data[['Mat Ice Rating', 'Kada Ice Rating']].plot.hist(title='Histogram Visual', bins=14,
                                                      color=['navy','royalblue', 'cornflowerblue'])
plt.show()

# %%
data.plot.barh(figsize=(10,10), title='Barh Visual', color=['navy','royalblue', 'cornflowerblue'])
plt.show()

# %%
data.plot.pie(y="Mat Ice Rating", figsize=(13,10), title='Pie Visual',
              colors=['indigo','rebeccapurple', 'blueviolet','darkviolet','lightsteelblue'])
plt.show()

# %%
data.plot.scatter(y='Kada Ice Rating', x='Overall Rating', title='Scatter Visual')
plt.show()
